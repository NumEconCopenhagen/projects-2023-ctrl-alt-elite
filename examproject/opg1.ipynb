# %%
#Import packages
import numpy as np
from scipy import optimize
import sympy as sm
from sympy import Symbol
from sympy.solvers import solve
from sympy import *
sm.init_printing(use_unicode=True) # for pretty printing
from IPython.display import display
import matplotlib.pyplot as plt # baseline modul
import ipywidgets as widgets
from types import SimpleNamespace

# autoreload modules when code is run
# %load_ext autoreload
# %autoreload 2

# local modules
import opg1py
from opg1py import ConsModel
model = ConsModel()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# initializing the model
# calling.setup()

# %% [markdown]
# **Question 1:** Verify that the optimal labor supply choice is $L^{\star}(\tilde{w}) =\frac{-\kappa+\sqrt{\kappa^{2}+4\frac{\alpha}{\nu}\tilde{w}^2}}{2\tilde{w}}$, where $\tilde{w} = (1-\tau)w$, for $G\in\left\{1.0 , 2.0\right\}$.

# %%
# Solving the model for L*
model.solve_analytical()
# Out:
# ⎡           _______________⎤
# ⎢          ╱      2    2   ⎥
# ⎢   κ    ╲╱  4⋅α⋅w̃  + κ ⋅v⎥
# ⎢- ─── + ──────────────────⎥
# ⎣  2⋅w̃        2⋅√v⋅w̃      ⎦

# %% [markdown]
# **Question 2:** Illustrate how $L^{\star}(\tilde{w})$ depends on $w$.

# %%
# Create an instance of ConsModel
model = ConsModel()

model.par.alpha = 0.5
model.par.kappa = 1
model.par.v = 1/(2*(16**2))
model.par.tau = 0.3

# Solve the model analytically
model.plot1()
# Out:
# initializing the model
# calling.setup()

# %% [markdown]
# We now consider a government, who chooses $\tau$ and spend all of the taxes on government consumption so:
#
# $$
# G = \tau w L^{\star}((1-\tau)w)
# $$
#
# **Question 3:** Plot the implied $L$, $G$ and worker utility for a grid of $\tau$-values.

# %%
model = ConsModel()
model.par.alpha = 0.5
model.par.kappa = 1
model.par.v = 1/(2*(16**2))
model.par.w = 1

model.plot2()
# Out:
# initializing the model
# calling.setup()

# %% [markdown]
# **Question 4:** Find the socially optimal tax rate $\tau^{\star}\in(0,1)$ maximizing worker utility. Illustrate your result.

# %%
model.insert_func()
# Out:
#
#      ⎛                                                  0.5
#      ⎜          ⎛   _________________________          ⎞    ⎛   ______________
#      ⎜      0.5 ⎜  ╱        2                          ⎟    ⎜  ╱        2
# - log⎝16.0⋅τ   ⋅⎝╲╱  (1 - τ)  + 0.0009765625  - 0.03125⎠   ⋅⎝╲╱  (1 - τ)  + 0.
#
#
#
#                                                                           2
#                       0.5⎞        ⎛   _________________________          ⎞
# ___________          ⎞   ⎟        ⎜  ╱        2                          ⎟
#                      ⎟   ⎟   0.25⋅⎝╲╱  (1 - τ)  + 0.0009765625  - 0.03125⎠
# 0009765625  + 0.03125⎠   ⎠ + ──────────────────────────────────────────────
#                                                        2
#                                                 (1 - τ)

# %%
model = ConsModel()
model.min_util()
# Out:
# initializing the model
# calling.setup()
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 3460, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\emok\AppData\Local\Temp\ipykernel_31512\1115095677.py", line 2, in <module>
#     model.max_util()
#   File "c:\Users\emok\OneDrive - Implement\Skrivebord\New_folder\projects-2023-ctrl-alt-elite\examproject\opg1py.py", line 182, in max_util
#     result = optimize.minimize_scalar(self.insert_func, bounds=(0.01, 0.99), method='bounded')
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\scipy\optimize\_minimize.py", line 913, in minimize_scalar
#     return _minimize_scalar_bounded(fun, bounds, args, **options)
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\scipy\optimize\_optimize.py", line 2213, in _minimize_scalar_bounded
#     fx = func(x, *args)
# TypeError: ConsModel.insert_func() takes 1 positional argument but 2 were given
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\IPython\core\interactiveshell.py", line 2057, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\IPython\core\ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\stack_data\core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\stack_data\core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\stack_data\utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\stack_data\core.py", line 628, in executing_piece
#     return only(
#   File "c:\Users\emok\AppData\Local\anaconda3\lib\site-packages\executing\executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0
